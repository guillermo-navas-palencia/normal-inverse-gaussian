# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from mpmath_integration import quad_phi

# %%
# instance = '../code/tests/results/test_general_small.csv'
# instance = '../code/tests/results/test_general_small_mpmath_accurate.csv'
# instance = '../code/tests/results/test_general_large.csv'
instance = '../code/tests/results/test_general_large_mpmath_accurate.csv'

# %%
df = pd.read_csv(instance)

# %%
df.head()
# Out:
#           x      alpha       beta        mu      delta         mpmath  \
# 0 -1.533471  42.299277  15.624322  8.618752  48.716240  5.842766e-154
# 1 -3.405366  39.369957  22.564907 -3.367453  34.051080  6.128768e-108
# 2  5.533662  25.199775  13.842587  7.044730  47.811741   8.599937e-98
# 3  2.826563  33.478599  22.944718  3.791948  19.420557   4.103635e-89
# 4 -8.368948  25.371659   4.319610  9.063795  23.393823  1.040752e-102
#
#            scipy            gnp
# 0  3.157781e-154  5.842766e-154
# 1  5.227174e-108  6.128768e-108
# 2   7.754948e-98   8.599937e-98
# 3   4.128919e-89  -1.585122e-86
# 4  1.051340e-102  1.040752e-102

# %%
df.loc[df['scipy'] == 'NAN', 'scipy'] = np.NaN
df['scipy'] = df['scipy'].astype(float)

df.loc[df['gnp'] == 'NAN', 'gnp'] = np.NaN
df['gnp'] = df['gnp'].astype(float)

# %%
df['relerr_gnp'] = np.absolute(df['gnp'] / df['mpmath'] - 1)
df['abs_gnp'] = np.absolute(df['gnp'] - df['mpmath'])

# %%
df['relerr_scipy'] = np.absolute(df['scipy'] / df['mpmath'] - 1)
df['abs_scipy'] = np.absolute(df['scipy'] - df['mpmath'])

# %%
df.describe()
# Out:
#                 x       alpha        beta          mu       delta  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000
# mean    -2.083654   30.535944   16.640513    2.042884   26.528073
# std      5.287105   12.931833   13.771291    5.503376   14.300254
# min     -9.918784    1.018661  -42.124406   -9.999683    0.045417
# 25%     -6.510664   21.236460    9.330765   -2.460904   14.893521
# 50%     -3.103620   32.014855   17.370046    3.310422   27.072276
# 75%      1.936057   41.461814   25.267061    6.808053   39.067090
# max      9.908819   49.963007   47.936804    9.990792   49.907165
#
#               mpmath          scipy            gnp    relerr_gnp  \
# count   7.040000e+02   7.040000e+02   7.040000e+02  7.040000e+02
# mean    3.139921e-02   3.139921e-02  -4.814622e-02           inf
# std     1.715458e-01   1.715458e-01   2.317294e-01           NaN
# min     0.000000e+00   0.000000e+00  -1.000000e+00  2.220446e-16
# ...

# %%
mask_inf = df['relerr_gnp'] == np.inf
mask_nan = (df['relerr_gnp'].isna() & (df['mpmath'] != df['gnp']) & (df['mpmath'] != 0))

mask_err = (df['relerr_gnp'] > 5e-13)  & (df['mpmath'] != 0)

# %%
mask_inf.sum(), mask_nan.sum()
# Out:
# (18, 0)

# %%
df[mask_inf]
# Out:
#             x      alpha       beta        mu      delta  mpmath  \
# 7    1.790041  46.272717  36.559569  5.417108  35.613161     0.0
# 11  -7.881575  42.285533  21.514654  8.417524  20.323675     0.0
# 23  -4.757064  38.139354  27.040722  6.807131  24.909433     0.0
# 108 -5.785889  39.218502  37.406553 -7.130691  48.552818     0.0
# 115 -5.988927  45.986292  23.724464  9.133855  27.244705     0.0
# 146 -7.846766  41.717475  25.261628  6.356881  25.301927     0.0
# 206 -3.970037  38.281425  20.256248  8.811809   0.970069     0.0
# 260  6.902683  30.376485  26.827299  7.099053  42.836130     0.0
# 266  1.543545  49.041262  43.191955  2.556822  47.457060     0.0
# 270 -7.301645  27.845804  20.611922  7.767314  34.957531     0.0
# 365  1.914421  37.112755  32.477971  6.888841  28.326364     0.0
# 392  5.527012  43.534094  31.929042  9.263262  45.021127     0.0
# 402 -8.533284  20.268803  19.624237  0.642121  34.575598     0.0
# ...

# %%
mask_err.sum(), (df['relerr_gnp'] > 1e-10).sum()
# Out:
# (686, 611)

# %%
df[mask_err].sort_values('relerr_gnp', ascending=False).head(30)
# Out:
#              x      alpha       beta        mu      delta         mpmath  \
# 2387 -9.036223  31.408403  28.007420 -7.605223  32.742378  2.637822e-264
# 3809  2.689383  47.076609  33.519016  4.107595  27.483531  8.664602e-209
# 3307 -0.686370  46.375306  44.142132  0.154904  11.350590  5.483779e-183
# 4263  6.099923  41.454912  37.043040  7.471298  15.236024  9.713311e-182
# 3933 -9.845860  42.088040  28.507553 -8.558329  25.416302  1.824572e-160
# 1133 -1.839166  41.461135  26.962406 -0.568860  26.444771  7.545115e-160
# 2260  4.059765  35.859761  24.170824  5.528006  28.712546  2.128278e-145
# 2165  5.898356  34.198042  21.475268 -3.112213  49.825304  9.326848e-152
# 2878  1.634176  33.216541  26.854377 -7.803308  47.921033  7.445174e-242
# 4121  7.771123  33.049287  29.196090 -6.467594  46.304220  6.004318e-256
# 537   9.847775  49.741798  31.908418  5.443828  35.245371  1.229670e-167
# 2203 -1.999397  32.041408  23.669382 -8.832425  46.501259  1.992244e-197
# ...

# %%
df[~mask_err].sort_values('relerr_gnp', ascending=False).head(20)
# Out:
#              x      alpha       beta        mu      delta        mpmath  \
# 2608  1.914421  37.112755  32.477971  6.888841  28.326364  0.000000e+00
# 4189 -8.875400  38.103036   6.381285  8.433771   0.598845  0.000000e+00
# 3481  1.855889  47.784904  33.399132  4.933983  49.096343  0.000000e+00
# 1104 -7.846766  41.717475  25.261628  6.356881  25.301927  0.000000e+00
# 1941 -7.301645  27.845804  20.611922  7.767314  34.957531  0.000000e+00
# 1916  1.543545  49.041262  43.191955  2.556822  47.457060  0.000000e+00
# 2759  5.527012  43.534094  31.929042  9.263262  45.021127  0.000000e+00
# 1858  6.902683  30.376485  26.827299  7.099053  42.836130  0.000000e+00
# 852  -5.988927  45.986292  23.724464  9.133855  27.244705  0.000000e+00
# 187  -4.757064  38.139354  27.040722  6.807131  24.909433  0.000000e+00
# 1539 -3.970037  38.281425  20.256248  8.811809   0.970069  0.000000e+00
# 789  -5.785889  39.218502  37.406553 -7.130691  48.552818  0.000000e+00
# ...

# %%
df[~mask_err].describe()
# Out:
#                  x        alpha         beta           mu        delta  \
# count  4314.000000  4314.000000  4314.000000  4314.000000  4314.000000
# mean      0.271824    24.545394    -2.994056    -0.382468    24.680732
# std       5.790238    14.600237    15.708897     5.803812    14.181832
# min      -9.998079     0.006625   -49.535976    -9.999682     0.017730
# 25%      -4.710344    11.529709   -11.878274    -5.428441    12.658882
# 50%       0.393698    24.340009    -1.832639    -0.681351    24.626059
# 75%       5.374989    36.932140     4.854153     4.537563    36.773211
# max       9.995823    49.992790    47.990420     9.994479    49.995046
#
#              mpmath         scipy           gnp    relerr_gnp       abs_gnp  \
# count  4.314000e+03  4.314000e+03  4.314000e+03  4.196000e+03  4.314000e+03
# mean   5.840884e-01  5.785251e-01  5.824657e-01           inf  1.622624e-03
# std    4.739053e-01  4.748590e-01  4.776008e-01           NaN  4.025378e-02
# ...

# %%
df[mask_err].describe()
# Out:
# C:\Users\guillermo\anaconda3\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: overflow encountered in square
#   sqr = _ensure_numeric((avg - values) ** 2)
#                 x       alpha        beta          mu       delta  \
# count  686.000000  686.000000  686.000000  686.000000  686.000000
# mean    -2.078959   30.276258   16.292551    1.980394   26.427403
# std      5.279402   12.940677   13.679279    5.504368   14.301011
# min     -9.918784    1.018661  -42.124406   -9.999683    0.045417
# 25%     -6.502833   20.808852    9.136983   -2.510760   14.503633
# 50%     -3.063083   31.575794   17.167255    3.225756   26.904236
# 75%      2.018334   41.032740   24.784733    6.720297   39.023737
# max      9.908819   49.963007   47.936804    9.990792   49.907165
#
#               mpmath          scipy            gnp     relerr_gnp  \
# count   6.860000e+02   6.860000e+02   6.860000e+02   6.860000e+02
# mean    3.222310e-02   3.222310e-02  -3.920545e-02  5.526249e+260
# ...

# %%
df[~mask_err & ~mask_inf].describe()
# Out:
#                  x        alpha         beta           mu        delta  \
# count  4296.000000  4296.000000  4296.000000  4296.000000  4296.000000
# mean      0.282443    24.478826    -3.131888    -0.402608    24.656917
# std       5.788812    14.586121    15.582305     5.798910    14.178894
# min      -9.998079     0.006625   -49.535976    -9.999682     0.017730
# 25%      -4.661992    11.489637   -11.988257    -5.444707    12.637189
# 50%       0.397549    24.244076    -1.884117    -0.704694    24.543699
# 75%       5.384551    36.765752     4.736866     4.502579    36.768041
# max       9.995823    49.992790    47.990420     9.994479    49.995046
#
#              mpmath         scipy           gnp    relerr_gnp       abs_gnp  \
# count  4.296000e+03  4.296000e+03  4.296000e+03  4.178000e+03  4.296000e+03
# mean   5.865357e-01  5.809491e-01  5.865357e-01  1.092791e-14  6.316600e-16
# std    4.733832e-01  4.743707e-01  4.733832e-01  3.685287e-14  5.707371e-15
# ...

# %%
df[~mask_err & ~mask_inf & (df['relerr_scipy'] != np.inf)].describe()
# Out:
#                  x        alpha         beta           mu        delta  \
# count  4295.000000  4295.000000  4295.000000  4295.000000  4295.000000
# mean      0.282143    24.478578    -3.138411    -0.402668    24.654010
# std       5.789452    14.587811    15.578252     5.799584    14.179264
# min      -9.998079     0.006625   -49.535976    -9.999682     0.017730
# 25%      -4.665077    11.488896   -11.991569    -5.444914    12.636167
# 50%       0.397092    24.236254    -1.886798    -0.706374    24.531547
# 75%       5.386836    36.770645     4.734755     4.502873    36.762573
# max       9.995823    49.992790    47.990420     9.994479    49.995046
#
#              mpmath         scipy           gnp    relerr_gnp       abs_gnp  \
# count  4.295000e+03  4.295000e+03  4.295000e+03  4.178000e+03  4.295000e+03
# mean   5.866722e-01  5.810843e-01  5.866722e-01  1.092791e-14  6.318071e-16
# std    4.733537e-01  4.743431e-01  4.733537e-01  3.685287e-14  5.708027e-15
# ...

# %%
df[~mask_err & ~mask_inf & (df['relerr_scipy'] != np.inf)].describe()

# %%
df_err = df[mask_err].sort_values('relerr_gnp', ascending=False).copy()

# %%
df_err = df_err.reset_index(drop=True)

# %%
df_err.shape
# Out:
# (686, 12)

# %%
df_err.head()
# Out:
#           x      alpha       beta        mu      delta         mpmath  \
# 0 -9.036223  31.408403  28.007420 -7.605223  32.742378  2.637822e-264
# 1  2.689383  47.076609  33.519016  4.107595  27.483531  8.664602e-209
# 2 -0.686370  46.375306  44.142132  0.154904  11.350590  5.483779e-183
# 3  6.099923  41.454912  37.043040  7.471298  15.236024  9.713311e-182
# 4 -9.845860  42.088040  28.507553 -8.558329  25.416302  1.824572e-160
#
#            scipy  gnp     relerr_gnp  abs_gnp  relerr_scipy      abs_scipy
# 0  4.516853e-265 -1.0  3.791007e+263      1.0  8.287658e-01  2.186136e-264
# 1  1.785331e-191 -1.0  1.154121e+208      1.0  2.060489e+17  1.785331e-191
# 2  8.815673e-178 -1.0  1.823560e+182      1.0  1.607581e+05  8.815618e-178
# 3  7.027383e-177 -1.0  1.029515e+181      1.0  7.234697e+04  7.027286e-177
# 4  6.559580e-142 -1.0  5.480737e+159      1.0  3.595133e+18  6.559580e-142

# %%
idx = 3
df_err.iloc[idx].mpmath, df_err.iloc[idx].gnp

# %%
x, alpha, beta, mu, delta = df_err.iloc[idx][['x', 'alpha', 'beta', 'mu', 'delta']]
x, alpha, beta, mu, delta

# %%
mp_result = quad_phi(x, alpha, beta, mu, delta, digits=300, b=1)
mp_result

# %% [markdown]
# #### 1. Decision tree (test for more complex cases)

# %%
from sklearn import tree

# %%
df['target'] = (~mask_err).astype(int)

# %%
df.head()

# %%
df['target'].describe()

# %%
df['target'].sum()

# %%
df.describe()

# %%
df['omega'] = np.sqrt(df['delta'] ** 2 + (df['x'] - df['mu']) ** 2)
df['gamma'] = np.sqrt(df['alpha'] ** 2 - df['beta'] ** 2)
df['xmu'] = df['x'] - df['mu']
df['xmu2'] = df['xmu'] ** 2
df['aw'] = df['alpha'] * df['omega']
df['aow'] = df['alpha'] / df['omega']
df['woa'] = df['omega'] / df['alpha']
df['da'] = df['delta'] * df['alpha']
df['abs_beta'] = df['beta'].abs()
df['rba'] = df['abs_beta'] / df['alpha']

# %%
# Algorithmic choice
df['target'] = (~mask_err).astype(int)

df['omega'] = np.sqrt(df['delta'] ** 2 + (df['x'] - df['mu']) ** 2)
df['gamma'] = np.sqrt(df['alpha'] ** 2 - df['beta'] ** 2)
df['aw'] = df['alpha'] * df['omega']
df['xmu'] = df['x'] - df['mu']
df['xmu2'] = df['xmu'] ** 2
df['aow'] = df['alpha'] / df['omega']
df['woa'] = df['omega'] / df['alpha']
df['da'] = df['delta'] * df['alpha']
df['absbeta'] = df['beta'].abs()

df['method'] = 'integration'

criteria_asymp_mu_1 = (df['xmu2'] >= 100) & (df['alpha'] >= 0.25 * df['omega'])
criteria_asymp_mu_2 = (df['gamma'] >= 10) & (df['alpha'] >= 5 * df['absbeta']) & (df['delta'] <= 10)
criteria_asymp_mu = criteria_asymp_mu_1 & criteria_asymp_mu_2
df.loc[criteria_asymp_mu, 'method'] = 'asymptotic_mu'

criteria_asymp_delta_1 = (df['absbeta'] >= 0.5 * df['alpha']) & (df['delta'] >= 15)
criteria_asymp_delta_2 = (df['xmu2'] <= 20) & (df['alpha'] >= 5)
criteria_asymp_delta = criteria_asymp_delta_1 & criteria_asymp_delta_2
df.loc[criteria_asymp_delta, 'method'] = 'asymptotic_delta'

criteria_bxmu_1 = (df['xmu2'] <= 3) & (df['delta'] >= 1)
criteria_bxmu_2 = (df['absbeta'] <= 1.5) & (df['gamma'] >= 0.75)
criteria_bxmu = criteria_bxmu_1 & criteria_bxmu_2
df.loc[criteria_bxmu, 'method'] = 'bessel_series_xmu'

criteria_hxmu = (df['xmu2'] <= 2.25) & (df['delta'] >= 2.5)
df.loc[criteria_hxmu, 'method'] = 'hermite_series_xmu'

criteria_hb_1 = (df['absbeta'] <= 1) & (df['gamma'] >= 1.5)
criteria_hb_2 = (df['absbeta'] <= 0.5) & (df['gamma'] >= 0.75)
criteria_hb = criteria_hb_1 & criteria_hb_2
df.loc[criteria_hb, 'method'] = 'hermite_series_beta'

# %%
df['method'][~mask_inf].value_counts()

# %%
df.groupby('method')[['target', 'relerr_gnp']].describe()

# %%
df[~mask_inf].groupby('method')[['target', 'relerr_gnp']].describe()

# %%
df[~mask_err & ~mask_inf].groupby('method')[['target', 'relerr_gnp']].describe()

# %%
df_check = df[df['method'] == 'asymptotic_mu']
df_check.sort_values('relerr_gnp', ascending=False)

# %%
X = df[['alpha', 'delta', 'aw', 'xmu2', 'aow', 'woa', 'da', 'omega', 'abs_beta', 'gamma', 'rba']]
y = df['target']

# %%
clf = tree.DecisionTreeClassifier(max_depth=4)
clf = clf.fit(X, y)

# %%
clf.score(X, y)

# %%
fig = plt.figure(figsize=(18, 4))
tree.plot_tree(clf, feature_names=X.columns, filled=True, fontsize=6)

# %%
mask_series = (df['xmu2'] <= 1.5) & (df['abs_beta'] <= 0.75) & (df['woa'] <= 0.3)
mask_series = (df['xmu2'] <= 1.5) & (df['delta'] >= 2.5) & (df['alpha'] <= 10.0)

mask_series = (df['xmu2'] >= 100) & (df['aow'] >= 0.25)

df[mask_series].describe()

# %%
cols = ['x', 'alpha', 'beta', 'mu', 'delta', 'mpmath', 'scipy', 'gnp',
       'relerr_gnp', 'abs_gnp', 'relerr_scipy', 'abs_scipy']

df.loc[mask_series, cols].sort_values('relerr_gnp', ascending=True).head(200)
